# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnElvisMedeirosCosta/Bootcamp-IGTI-Analise-de-dados/blob/master/Primeiro_Projeto_IGTI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#setando as bibliotecas
from math import sqrt
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
#criando o dataset
X, y = make_blobs(n_samples=500, centers=20, random_state=999)

plt.scatter(X[:,0], X[:,1])

# %%
#analisando os clusters
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 20), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid()
plt.show()

# %%
#calculando o cluster perfeito
def optimal_number_of_clusters(wcss):
    x1, y1 = 1, wcss[0]
    x2, y2 = 20, wcss[len(wcss)-1]
    distances = []
    for i in range(len(wcss)):
        x0 = i+2
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
    return distances.index(max(distances)) + 2

# %%
kmeans = KMeans(n_clusters=1, init='k-means++', max_iter=300, n_init=10)
kmeans.fit(X)
wcss.append(kmeans.inertia_)
print('Soma dos quadrados de 1 cluster')
print(kmeans.inertia_)
# Out:
# Soma dos quadrados de 1 cluster
# 31547.372471390485

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10)
kmeans.fit(X)
wcss.append(kmeans.inertia_)
print('Soma dos quadrados de 5 clusters')
print(kmeans.inertia_)
# Out:
# Soma dos quadrados de 5 clusters
# 4717.404091931214

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10)
kmeans.fit(X)
wcss.append(kmeans.inertia_)
print('Soma dos quadrados de 4 clusters')
print(kmeans.inertia_)
# Out:
# Soma dos quadrados de 4 clusters
# 6005.101775346179

# %%
soma = optimal_number_of_clusters(wcss)
print('Quantidade ótima de clusters')
print(soma)
# Out:
# Quantidade ótima de clusters
# 5
